# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import yfinance as yf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# %%
#Data collection
data = yf.download(tickers='AAPL', start='2015-1-1', end='2023-12-31')
data = data['Close']
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker            AAPL
# Date
# 2015-01-02   27.332500
# 2015-01-05   26.562500
# 2015-01-06   26.565001
# 2015-01-07   26.937500
# 2015-01-08   27.972500
# ...                ...
# 2023-12-22  193.600006
# 2023-12-26  193.050003
# 2023-12-27  193.149994
# 2023-12-28  193.580002
# 2023-12-29  192.529999
#
# [2264 rows x 1 columns]

# %%
# Data collection for future accuracy checking
actual_df = yf.download(tickers='AAPL',start='2023-12-28',end='2024-1-31')
actual_df = actual_df['Close']
actual_df.columns = ['Close']
actual_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Close
# Date
# 2023-12-28  193.580002
# 2023-12-29  192.529999
# 2024-01-02  185.639999
# 2024-01-03  184.250000
# 2024-01-04  181.910004
# 2024-01-05  181.179993
# 2024-01-08  185.559998
# 2024-01-09  185.139999
# 2024-01-10  186.190002
# 2024-01-11  185.589996
# 2024-01-12  185.919998
# 2024-01-16  183.630005
# 2024-01-17  182.679993
# 2024-01-18  188.630005
# 2024-01-19  191.559998
# 2024-01-22  193.889999
# 2024-01-23  195.179993
# 2024-01-24  194.500000
# 2024-01-25  194.169998
# 2024-01-26  192.419998
# 2024-01-29  191.729996
# 2024-01-30  188.039993

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

# Create sequences
def create_sequences(data, seq_length):
    x, y = [], []
    for i in range(len(data) - seq_length):
        x.append(data[i:i + seq_length, 0])
        y.append(data[i + seq_length, 0])
    return np.array(x), np.array(y)

sequence_length = 50
x, y = create_sequences(data_scaled, sequence_length)

# %%
# Reshape input to [samples, time steps, features]
x = np.reshape(x, (x.shape[0], x.shape[1], 1))

# %%
# Split into training and testing sets
train_size = int(len(x) * 0.8)
x_train, x_test = x[:train_size], x[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
x_train
# Out:
# array([[[0.02704744],
#         [0.02266059],
#         [0.02267484],
#         ...,
#         [0.04858282],
#         [0.04735793],
#         [0.04929497]],
#
#        [[0.02266059],
#         [0.02267484],
#         [0.02479704],
#         ...,
#         [0.04735793],
#         [0.04929497],
#         [0.05227176]],
#
#        [[0.02267484],
#         [0.02479704],
#         [0.03069364],
#         ...,
#         [0.04929497],
#         [0.05227176],
#         [0.05430851]],
#
#        ...,
#
#        [[0.85232874],
#         [0.86879363],
#         [0.87135735],
#         ...,
#         [0.80555474],
#         [0.81353086],
#         [0.83312922]],
#
#        [[0.86879363],
#         [0.87135735],
#         [0.85232874],
#         ...,
#         [0.81353086],
#         [0.83312922],
#         [0.84104832]],
#
#        [[0.87135735],
#         [0.85232874],
#         [0.8573423 ],
#         ...,
#         [0.83312922],
#         [0.84104832],
#         [0.86303949]]])

# %%
# Build the LSTM model
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(sequence_length, 1)),
    LSTM(50, return_sequences=False),
    Dense(25, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Training model
model.fit(x_train, y_train, batch_size=32, epochs=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 66ms/step - loss: 0.0471 - val_loss: 0.0022
# Epoch 2/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 4.5048e-04 - val_loss: 0.0019
# Epoch 3/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 4.1972e-04 - val_loss: 0.0020
# Epoch 4/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 3.9219e-04 - val_loss: 0.0018
# Epoch 5/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 4.0412e-04 - val_loss: 0.0020
# Epoch 6/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 4.2225e-04 - val_loss: 0.0021
# Epoch 7/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.0893e-04 - val_loss: 0.0014
# Epoch 8/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 3.3035e-04 - val_loss: 0.0014
# Epoch 9/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 3.6924e-04 - val_loss: 0.0013
# Epoch 10/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.1833e-04 - val_loss: 0.0015
# Epoch 11/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.2253e-04 - val_loss: 0.0011
# Epoch 12/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.6017e-04 - val_loss: 0.0011
# Epoch 13/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 3.1334e-04 - val_loss: 0.0015
# Epoch 14/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.0491e-04 - val_loss: 0.0010
# Epoch 15/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 2.9622e-04 - val_loss: 9.4153e-04
# Epoch 16/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 3.1946e-04 - val_loss: 0.0010
# Epoch 17/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 2.9264e-04 - val_loss: 9.7057e-04
# Epoch 18/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 3.0689e-04 - val_loss: 0.0012
# Epoch 19/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 3.9785e-04 - val_loss: 9.5666e-04
# Epoch 20/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 2.6988e-04 - val_loss: 9.6848e-04
# Epoch 21/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.1362e-04 - val_loss: 8.0689e-04
# Epoch 22/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 2.4460e-04 - val_loss: 7.3835e-04
# Epoch 23/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 2.8462e-04 - val_loss: 9.5595e-04
# Epoch 24/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 2.6912e-04 - val_loss: 8.9185e-04
# Epoch 25/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 1.9809e-04 - val_loss: 7.1300e-04
# Epoch 26/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 2.1493e-04 - val_loss: 6.9412e-04
# Epoch 27/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 2.1320e-04 - val_loss: 7.3398e-04
# Epoch 28/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 2.1865e-04 - val_loss: 6.3434e-04
# Epoch 29/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 1.8542e-04 - val_loss: 0.0019
# Epoch 30/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 2.6367e-04 - val_loss: 6.3179e-04
# Epoch 31/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 2.0991e-04 - val_loss: 7.2467e-04
# Epoch 32/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 1.8635e-04 - val_loss: 5.6106e-04
# Epoch 33/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 1.7597e-04 - val_loss: 5.7036e-04
# Epoch 34/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 2.0274e-04 - val_loss: 6.6257e-04
# Epoch 35/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1.8958e-04 - val_loss: 9.4653e-04
# Epoch 36/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1.9581e-04 - val_loss: 5.7170e-04
# Epoch 37/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 2.0878e-04 - val_loss: 4.8928e-04
# Epoch 38/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 1.7697e-04 - val_loss: 4.8146e-04
# Epoch 39/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 1.7756e-04 - val_loss: 9.4822e-04
# Epoch 40/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 2.6195e-04 - val_loss: 4.7342e-04
# Epoch 41/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1.5818e-04 - val_loss: 4.5322e-04
# Epoch 42/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 1.6962e-04 - val_loss: 4.4787e-04
# Epoch 43/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 1.4006e-04 - val_loss: 5.0517e-04
# Epoch 44/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 1.5237e-04 - val_loss: 4.4467e-04
# Epoch 45/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - loss: 1.6269e-04 - val_loss: 5.5332e-04
# Epoch 46/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - loss: 2.1248e-04 - val_loss: 7.6791e-04
# Epoch 47/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - loss: 1.5365e-04 - val_loss: 0.0011
# Epoch 48/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - loss: 2.0163e-04 - val_loss: 5.9470e-04
# Epoch 49/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - loss: 1.3699e-04 - val_loss: 6.1794e-04
# Epoch 50/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - loss: 2.1118e-04 - val_loss: 3.6558e-04

# %%
# Predict using test set
y_pred_scaled = model.predict(x_test)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step

# %%
# Inverse transform the scaled data
y_test = scaler.inverse_transform([y_test]).flatten()
y_pred = scaler.inverse_transform(y_pred_scaled).flatten()

#y_test
#y_pred

# %%
# Plot results
plt.figure(figsize=(10, 6))
plt.plot(data.index[-len(y_test):], y_test, label='True Value', color='blue')
plt.plot(data.index[-len(y_test):], y_pred, label='Predicted Value', color='red')
plt.legend()
plt.title('LSTM Model Forecasting')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %% [markdown]
# **Prediction Accuracy**

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mean_actual = np.mean(y_test)

# Accuracy Calculation
accuracy = 100 - (rmse / mean_actual * 100)

print(f"RMSE: {rmse:.2f}")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# RMSE: 3.36
# Accuracy: 97.94%

# %% [markdown]
# **Forecasting**

# %%
# Forecast future steps
def forecast_future(model, recent_data, n_steps):
    predictions = []
    current_input = recent_data.copy()

    for _ in range(n_steps):
        prediction = model.predict(current_input[np.newaxis, :, np.newaxis])
        predictions.append(prediction[0, 0])
        current_input = np.roll(current_input, -1)
        current_input[-1] = prediction

    return np.array(predictions)

# Forecast next 30 days
recent_data = data_scaled[-sequence_length:].flatten()
future_steps = 22
future_forecast_scaled = forecast_future(model, recent_data, future_steps)
future_forecast = scaler.inverse_transform(future_forecast_scaled.reshape(-1, 1)).flatten()

print("Future Forecast (Next 30 Days):", future_forecast)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# C:\Users\Prerana Walvekar\AppData\Local\Temp\ipykernel_8316\1723330635.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   current_input[-1] = prediction
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Future Forecast (Next 30 Days): [191.85417 191.37677 190.81143 190.22198 189.63635 189.06834 188.52487
#  188.00856 187.51958 187.05644 186.61684 186.19821 185.79802 185.41386
#  185.04361 184.68553 184.33815 184.00008 183.67044 183.34813 183.03236
#  182.72249]

# %%
plt.figure(figsize=(10, 6))

# Plot historical true values
plt.plot(data.index[-len(y_test):], y_test, label="True Values", color='blue')

# Plot historical predictions
plt.plot(data.index[-len(y_test):], y_pred, label="Predicted Values", color='red')

# Plot actual values
plt.plot(actual_df['Close'],label='Actual',color='Black')

# Plot future forecast
future_dates = [data.index[-1] + pd.Timedelta(days=i) for i in range(1, future_steps + 1)]
plt.plot(future_dates, future_forecast, label="Future Forecast", color='green')

# Show plot
plt.title("LSTM Forecast")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Prediction**

# %%
future_actual_prices = actual_df['Close'].values

# %%
# Calculate Mean Absolute Percentage Error (MAPE)
mape_forecast = np.mean(np.abs((future_actual_prices - future_forecast) / future_actual_prices)) * 100

# Calculate accuracy
accuracy_forecast = 100 - mape_forecast

# Print results
print(f"Forecasting Accuracy: {accuracy_forecast:.2f}%")
print(f"MAPE for Forecasting: {mape_forecast:.2f}%")
# Out:
# Forecasting Accuracy: 97.16%
# MAPE for Forecasting: 2.84%
