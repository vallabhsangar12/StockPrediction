# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import yfinance as yf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# %%
#Data collection
data = yf.download(tickers='MCD', start='2015-1-1', end='2023-12-31')
data = data['Close']
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker             MCD
# Date
# 2015-01-02   93.260002
# 2015-01-05   92.230003
# 2015-01-06   92.400002
# 2015-01-07   94.010002
# 2015-01-08   94.360001
# ...                ...
# 2023-12-22  291.700012
# 2023-12-26  292.859985
# 2023-12-27  294.549988
# 2023-12-28  295.839996
# 2023-12-29  296.510010
#
# [2264 rows x 1 columns]

# %%
# Data collection for future accuracy checking
actual_df = yf.download(tickers='MCD',start='2023-12-31',end='2024-1-31')
actual_df = actual_df['Close']
actual_df.columns = ['Close']
actual_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Close
# Date
# 2024-01-02  297.040009
# 2024-01-03  294.390015
# 2024-01-04  291.739990
# 2024-01-05  288.989990
# 2024-01-08  291.899994
# 2024-01-09  290.869995
# 2024-01-10  294.089996
# 2024-01-11  294.149994
# 2024-01-12  293.470001
# 2024-01-16  291.089996
# 2024-01-17  291.160004
# 2024-01-18  294.359985
# 2024-01-19  300.529999
# 2024-01-22  298.410004
# 2024-01-23  300.049988
# 2024-01-24  300.440002
# 2024-01-25  297.209991
# 2024-01-26  292.260010
# 2024-01-29  292.309998
# 2024-01-30  294.649994

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

# Create sequences
def create_sequences(data, seq_length):
    x, y = [], []
    for i in range(len(data) - seq_length):
        x.append(data[i:i + seq_length, 0])
        y.append(data[i + seq_length, 0])
    return np.array(x), np.array(y)

sequence_length = 50
x, y = create_sequences(data_scaled, sequence_length)

# %%
# Reshape input to [samples, time steps, features]
x = np.reshape(x, (x.shape[0], x.shape[1], 1))

# %%
# Split into training and testing sets
train_size = int(len(x) * 0.8)
x_train, x_test = x[:train_size], x[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
x_train
# Out:
# array([[[0.021371  ],
#         [0.01645759],
#         [0.01726853],
#         ...,
#         [0.03563422],
#         [0.03611124],
#         [0.0399275 ]],
#
#        [[0.01645759],
#         [0.01726853],
#         [0.02494873],
#         ...,
#         [0.03611124],
#         [0.0399275 ],
#         [0.03525258]],
#
#        [[0.01726853],
#         [0.02494873],
#         [0.02661834],
#         ...,
#         [0.0399275 ],
#         [0.03525258],
#         [0.03921195]],
#
#        ...,
#
#        [[0.83780948],
#         [0.82688543],
#         [0.82116114],
#         ...,
#         [0.71621426],
#         [0.69904119],
#         [0.712398  ]],
#
#        [[0.82688543],
#         [0.82116114],
#         [0.82349855],
#         ...,
#         [0.69904119],
#         [0.712398  ],
#         [0.70285738]],
#
#        [[0.82116114],
#         [0.82349855],
#         [0.80584835],
#         ...,
#         [0.712398  ],
#         [0.70285738],
#         [0.72260646]]])

# %%
# Build the LSTM model
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(sequence_length, 1)),
    LSTM(50, return_sequences=False),
    Dense(25, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Training model
model.fit(x_train, y_train, batch_size=32, epochs=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0971 - val_loss: 0.0068
# Epoch 2/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 9.3991e-04 - val_loss: 0.0075
# Epoch 3/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 9.3586e-04 - val_loss: 0.0043
# Epoch 4/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 8.8712e-04 - val_loss: 0.0025
# Epoch 5/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 8.5423e-04 - val_loss: 0.0025
# Epoch 6/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.8906e-04 - val_loss: 0.0018
# Epoch 7/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.6058e-04 - val_loss: 0.0023
# Epoch 8/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.3429e-04 - val_loss: 0.0021
# Epoch 9/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.3010e-04 - val_loss: 0.0019
# Epoch 10/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.8782e-04 - val_loss: 0.0016
# Epoch 11/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.4346e-04 - val_loss: 0.0012
# Epoch 12/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.1926e-04 - val_loss: 0.0015
# Epoch 13/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.4501e-04 - val_loss: 9.9937e-04
# Epoch 14/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.5925e-04 - val_loss: 9.0976e-04
# Epoch 15/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.1324e-04 - val_loss: 7.8169e-04
# Epoch 16/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.0065e-04 - val_loss: 7.9118e-04
# Epoch 17/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.6938e-04 - val_loss: 0.0010
# Epoch 18/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.2447e-04 - val_loss: 7.9870e-04
# Epoch 19/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1596e-04 - val_loss: 9.0039e-04
# Epoch 20/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.4096e-04 - val_loss: 6.5411e-04
# Epoch 21/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.7877e-04 - val_loss: 7.4045e-04
# Epoch 22/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.0612e-04 - val_loss: 0.0030
# Epoch 23/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.1729e-04 - val_loss: 8.7918e-04
# Epoch 24/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.6912e-04 - val_loss: 0.0022
# Epoch 25/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.6495e-04 - val_loss: 7.6357e-04
# Epoch 26/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.5852e-04 - val_loss: 4.4377e-04
# Epoch 27/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.6151e-04 - val_loss: 5.4867e-04
# Epoch 28/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.7235e-04 - val_loss: 5.5468e-04
# Epoch 29/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.4088e-04 - val_loss: 5.7109e-04
# Epoch 30/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.8770e-04 - val_loss: 5.7089e-04
# Epoch 31/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.4367e-04 - val_loss: 5.8063e-04
# Epoch 32/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.9934e-04 - val_loss: 0.0012
# Epoch 33/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.1395e-04 - val_loss: 3.9106e-04
# Epoch 34/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.7715e-04 - val_loss: 4.0049e-04
# Epoch 35/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.8137e-04 - val_loss: 0.0010
# Epoch 36/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.0325e-04 - val_loss: 5.5178e-04
# Epoch 37/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.4613e-04 - val_loss: 3.5773e-04
# Epoch 38/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.8570e-04 - val_loss: 6.9874e-04
# Epoch 39/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.9080e-04 - val_loss: 3.5823e-04
# Epoch 40/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.6568e-04 - val_loss: 4.2991e-04
# Epoch 41/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.8386e-04 - val_loss: 4.4676e-04
# Epoch 42/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.7839e-04 - val_loss: 3.0439e-04
# Epoch 43/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.3165e-04 - val_loss: 0.0010
# Epoch 44/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.2929e-04 - val_loss: 6.6903e-04
# Epoch 45/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.7969e-04 - val_loss: 4.8969e-04
# Epoch 46/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.5502e-04 - val_loss: 3.7410e-04
# Epoch 47/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.2210e-04 - val_loss: 0.0040
# Epoch 48/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.8126e-04 - val_loss: 4.6199e-04
# Epoch 49/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.3770e-04 - val_loss: 3.4504e-04
# Epoch 50/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.4608e-04 - val_loss: 2.8038e-04

# %%
# Predict using test set
y_pred_scaled = model.predict(x_test)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step

# %%
# Inverse transform the scaled data
y_test = scaler.inverse_transform([y_test]).flatten()
y_pred = scaler.inverse_transform(y_pred_scaled).flatten()

#y_test
#y_pred

# %%
# Plot results
plt.figure(figsize=(10, 6))
plt.plot(data.index[-len(y_test):], y_test, label='True Value', color='blue')
plt.plot(data.index[-len(y_test):], y_pred, label='Predicted Value', color='red')
plt.legend()
plt.title('LSTM Model Forecasting')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %% [markdown]
# **Prediction Accuracy**

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mean_actual = np.mean(y_test)

# Accuracy Calculation
accuracy = 100 - (rmse / mean_actual * 100)

print(f"RMSE: {rmse:.2f}")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# RMSE: 3.51
# Accuracy: 98.69%

# %% [markdown]
# **Forecasting**

# %%
# Forecast future steps
def forecast_future(model, recent_data, n_steps):
    predictions = []
    current_input = recent_data.copy()

    for _ in range(n_steps):
        prediction = model.predict(current_input[np.newaxis, :, np.newaxis])
        predictions.append(prediction[0, 0])
        current_input = np.roll(current_input, -1)
        current_input[-1] = prediction

    return np.array(predictions)

# Forecast next 30 days
recent_data = data_scaled[-sequence_length:].flatten()
future_steps = 30
future_forecast_scaled = forecast_future(model, recent_data, future_steps)
future_forecast = scaler.inverse_transform(future_forecast_scaled.reshape(-1, 1)).flatten()

print("Future Forecast (Next 30 Days):", future_forecast)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# C:\Users\Prerana Walvekar\AppData\Local\Temp\ipykernel_14632\876895309.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   current_input[-1] = prediction
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Future Forecast (Next 30 Days): [294.39758 294.7053  294.74268 294.67426 294.5736  294.47507 294.3726
#  294.23068 294.1158  294.02292 293.9505  293.89764 293.86316 293.8453
#  293.84204 293.85104 293.87    293.8966  293.92877 293.9646  294.0024
#  294.04092 294.07904 294.11588 294.15094 294.18384 294.2144  294.24246
#  294.26822 294.29178]

# %%
plt.figure(figsize=(10, 6))

# Plot historical true values
plt.plot(data.index[-len(y_test):], y_test, label="True Values", color='blue')

# Plot historical predictions
plt.plot(data.index[-len(y_test):], y_pred, label="Predicted Values", color='red')

# Plot actual values
plt.plot(actual_df['Close'],label='Actual',color='Black')

# Plot future forecast
future_dates = [data.index[-1] + pd.Timedelta(days=i) for i in range(1, future_steps + 1)]
plt.plot(future_dates, future_forecast, label="Future Forecast", color='green')

# Show plot|
plt.title("LSTM Forecast")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Prediction**

# %%
future_actual_prices = actual_df['Close'].values

# %%
# Calculate Mean Absolute Percentage Error (MAPE)
mape_forecast = np.mean(np.abs((future_actual_prices - future_forecast) / future_actual_prices)) * 100

# Calculate accuracy
accuracy_forecast = 100 - mape_forecast

# Print results
print(f"Forecasting Accuracy: {accuracy_forecast:.2f}%")
print(f"MAPE for Forecasting: {mape_forecast:.2f}%")
# Out:
# Forecasting Accuracy: 99.02%
# MAPE for Forecasting: 0.98%
